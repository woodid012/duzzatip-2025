# %%
import pandas as pd
from pymongo import MongoClient
import uuid

# MongoDB connection string
MONGODB_URI = "mongodb+srv://dbwooding88:HUz1BwQHnDjKJPjC@duzzatip.ohjmn.mongodb.net/?retryWrites=true&w=majority&appName=Duzzatip"

def connect_to_mongodb():
    client = MongoClient(MONGODB_URI)
    return client.afl_database

def generate_player_id():
    return str(uuid.uuid4())

def upload_players():
    # Read CSV file
    df = pd.read_csv('upload_list_2026.csv')
    
    # Connect to MongoDB
    db = connect_to_mongodb()
    collection = db['2026_players']
    
    # Prepare data for upload
    players_to_insert = []
    for _, row in df.iterrows():
        player_doc = {
            'player_id': generate_player_id(),
            'player_name': row['player'],
            'team_name': row['team']
        }
        players_to_insert.append(player_doc)
    
    try:
        # Delete existing 2026 players if any
        collection.delete_many({})
        
        # Insert new players
        result = collection.insert_many(players_to_insert)
        print(f"Successfully uploaded {len(result.inserted_ids)} players")
        
    except Exception as e:
        print(f"Error uploading players: {str(e)}")
    
if __name__ == "__main__":
    upload_players()
